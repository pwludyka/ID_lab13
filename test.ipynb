# %%
import os

print("GUARDRAILS_API_KEY exists:", bool(os.getenv("GUARDRAILS_API_KEY")))
print("OPENAI_API_KEY exists:", bool(os.getenv("OPENAI_API_KEY")))
# Out:
# GUARDRAILS_API_KEY exists: False
# OPENAI_API_KEY exists: False
